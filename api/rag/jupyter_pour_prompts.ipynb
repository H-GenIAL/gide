# %%
import pandas as pd
import sys
sys.stdout = open(sys.stdout.fileno(), mode='w', buffering=1)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[17], line 3
#       1 import pandas as pd
#       2 import sys
# ----> 3 sys.stdout = open(sys.stdout.fileno(), mode='w', buffering=1)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ipykernel\iostream.py:371, in OutStream.fileno(self)
#     369     return self._original_stdstream_copy
#     370 msg = "fileno"
# --> 371 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno

# %%
df = pd.read_csv('excel_keys.csv')

# %%
large_text = str(df[["datapoints", 'id']].values)

with open("output.txt", "w", encoding="utf-8") as f:
    f.write(large_text)

# Afficher le contenu complet du fichier
with open("output.txt", "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# [['Bailleur' 'bailleur']
#  ['Preneur' 'preneur']
#  ['Cession du droit du bail' 'cession']
#  ['Adresse' 'adresse']
#  ['Désignation des locaux' 'designation']
#  ['Destination des locaux loués et activités autorisées' 'dest_loc_act']
#  ["Clause d'enseigne" 'clause_enseigne']
#  ['Exclusivité' 'exclusivite']
#  ['Non-concurrence' 'non_concurrence']
#  ['Clause relative au classement des locaux loués en ERP'
#   'classemt_loc_erp']
#  ['Date de signature' 'date_sign']
#  ['Loi Pinel' 'pinel']
#  ["Date de prise d'effet" 'date_prise_effet']
#  ['Durée du Bail' 'duree_bail']
#  ['Terme contractuel du Bail' 'terme_contrat_bail']
#  ['Période ferme' 'periode_ferme']
#  ['Prochaine faculté de sortie' 'pro_fac_sortie']
#  ['Préavis minimum à respecter' 'preavis_min']
#  ['Clause spécifique relative à la durée du Bail renouvelé'
#   'clause_spe_duree_bail_renouv']
#  ['Mode de calcul du loyer fixe' 'mode_calc_fixe']
#  ['Mode de calcul du loyer paliers' 'mode_calc_paliers']
#  ['Mode de calcul du loyer Clause-recette' 'mode_calc_recette']
#  ['Loyer annuel (HT HC) initial' 'loyer_annuel_init']
#  ['Loyer annuel (HT HC) en cours' 'loyer_annuel_cours']
#  ["Paiement trimestriellement et d'avance" 'paiement_trim_av']
#  ['TVA expressément applicable' 'tva']
#  ["Clause d'indexation" 'clause_index']
#  ["Date d'indexation" 'date_index']
#  ["Périodicité de l'indexation" 'period_index']
#  ['Indice INSEE' 'indice_insee']
#  ['1ère indexation' 'premiere_index']
#  ['indexations suivantes' 'index_suivantes']
#  ['Indice de comparaison' 'indice_comparaison']
#  ['Indice de base fixe' 'indice_base_fixe']
#  ['Indexation à la hausse uniquement' 'index_hausse_uniqmt']
#  ['Plafond/Plancher' 'plafond_plancher']
#  ['Risque de distorsion' 'risque_distorsion']
#  ["Divisibilité de la clause d'indexation" 'divisibilite_clause_index']
#  ['Augmentation de 25% par comparaison avec le dernier loyer'
#   'augment_comp_dern_loyer']
#  ['Clause relative au loyer du Bail renouvelé' 'clause_loyer_bail_renouv']
#  ['Franchise et/ou réduction de loyer en cours (montant et étalement)'
#   'franchise_reduct_loyer']
#  ['Side letter TVA fournie en Data Room' 'side_letter_tva']
#  ["Autres mesures d'accompagnement" 'autres_mesures_accomp']
#  ['Dépôt de garantie' 'depot_garantie']
#  ['Autres garanties' 'autres_garanties']
#  ['Original de la garantie en possession du Bailleur'
#   'garantie_possess_b']
#  ['Nature' 'nature']
#  ['Garant' 'garant']
#  ['Montant' 'montant']
#  ['Expiration' 'expiration']
#  ['Transférabilité au nouveau bailleur' 'transfer_nb']
#  ['Parties privatives Bailleur Impôts futurs' 'ppb_impots']
#  ['Parties privatives Bailleur Taxe foncière' 'ppb_taxe_fonc']
#  ['Parties privatives Bailleur TEOM' 'ppb_teom']
#  ['Parties privatives Bailleur Taxe sur les locaux à usage de commerce'
#   'ppb_loc_comm']
#  ['Parties privatives Preneur Impôts futurs' 'ppp_impots']
#  ['Parties privatives Preneur Taxe foncière' 'ppp_taxe_fonc']
#  ['Parties privatives Preneur TEOM' 'ppp_teom']
#  ['Parties privatives Preneur Taxe sur les locaux à usage de commerce'
#   'ppp_loc_comm']
#  ['Parties privatives Non précisé Impôts futurs' 'pp_impots']
#  ['Parties privatives Non précisé Taxe foncière' 'pp_taxe_fonc']
#  ['Parties privatives Non précisé TEOM' 'pp_teom']
#  ['Parties privatives Non précisé Taxe sur les locaux à usage de commerce'
#   'pp_loc_comm']
#  ['Parties communes Bailleur Impôts futurs' 'pcb_impots']
#  ['Parties communes Bailleur Taxe foncière' 'pcb_taxe_fonc']
#  ['Parties communes Bailleur TEOM' 'pcb_teom']
#  ['Parties communes Bailleur Taxe sur les locaux à usage de commerce'
#   'pcb_loc_comm']
#  ['Parties communes Preneur Impôts futurs' 'pcp_impots']
#  ['Parties communes Preneur Taxe foncière' 'pcp_taxe_fonc']
#  ['Parties communes Preneur TEOM' 'pcp_teom']
#  ['Parties communes Preneur Taxe sur les locaux à usage de commerce'
#   'pcp_loc_comm']
#  ['Parties communes Non précisé Impôts futurs' 'pc_impots']
#  ['Parties communes Non précisé Taxe foncière' 'pc_taxe_fonc']
#  ['Parties communes Non précisé TEOM' 'pc_teom']
#  ['Parties communes Non précisé Taxe sur les locaux à usage de commerce'
#   'pc_loc_comm']
#  ['Honoraires Bailleur gestion technique' 'hb_gest_tech']
#  ['Honoraires Bailleur gestion locative' 'hb_gest_loc']
#  ['Honoraires Bailleur gestion des loyers' 'hb_gest_loyers']
#  ['Honoraires Bailleur gestion du syndic de copro' 'hb_gest_synd']
#  ['Honoraires Preneur gestion technique' 'hp_gest_tech']
#  ['Honoraires Preneur gestion locative' 'hp_gest_loc']
#  ['Honoraires Preneur gestion des loyers' 'hp_gest_loyers']
#  ['Honoraires Preneur gestion du syndic de copro' 'hp_gest_synd']
#  ['Honoraires Non précisé gestion technique' 'hnp_gest_tech']
#  ['Honoraires Non précisé gestion locative' 'hnp_gest_loc']
#  ['Honoraires Non précisé gestion des loyers' 'hnp_gest_loyers']
#  ['Honoraires Non précisé gestion du syndic de copro' 'hnp_gest_synd']
#  ['Assurances du Bailleur Bailleur' 'assu_b_b']
#  ['Assurances du Bailleur Preneur' 'assu_b_p']
#  ['Assurances du Bailleur Non précisé' 'assu_b_np']
#  ['Fonds Marketing' 'fonds_marktg']
#  ['Parties privatives Bailleur Grosses réparations' 'pp_b_rep']
#  ['Parties privatives Bailleur Mise en confo' 'pp_b_confo']
#  ['Parties privatives Bailleur Prise en charge de la vétusté'
#   'pp_b_vetus']
#  ["Parties privatives Bailleur Remplacement des éléments d'équipement"
#   'pp_b_equip']
#  ['Parties privatives Preneur Grosses réparations' 'pp_p_rep']
#  ['Parties privatives Preneur Mise en confo' 'pp_p_confo']
#  ['Parties privatives Preneur Prise en charge de la vétusté' 'pp_p_vetus']
#  ["Parties privatives Preneur remplacement des éléments d'équipement"
#   'pp_p_equip']
#  ['Parties privatives Non précisé Grosses réparations' 'pp_np_rep']
#  ['Parties privatives Non précisé Mise en confo' 'pp_np_confo']
#  ['Parties privatives Non précisé Prise en charge de la vétusté'
#   'pp_np_vetus']
#  ["Parties privatives Non précisé remplacement des éléments d'équipement"
#   'pp_np_equip']
#  ['Parties communes Bailleur Grosses réparations' 'pc_b_rep']
#  ['Parties communes Bailleur Mise en confo' 'pc_b_confo']
#  ['Parties communes Bailleur Prise en charge de la vétusté' 'pc_b_vetus']
#  ["Parties communes Bailleur Remplacement des éléments d'équipement"
#   'pc_b_equip']
#  ['Parties communes Preneur Grosses réparations' 'pc_p_rep']
#  ['Parties communes Preneur Mise en confo' 'pc_p_confo']
#  ['Parties communes Preneur Prise en charge de la vétusté' 'pc_p_vetus']
#  ["Parties communes Preneur remplacement des éléments d'équipement"
#   'pc_p_equip']
#  ['Parties communes Non précisé Grosses réparations' 'pc_np_rep']
#  ['Parties communes Non précisé Mise en confo' 'pc_np_confo']
#  ['Parties communes Non précisé Prise en charge de la vétusté'
#   'pc_np_vetus']
#  ["Parties communes Non précisé remplacement des éléments d'équipement"
#   'pc_np_equip']
#  ["Dérogation à l'article 1722" 'derog_1722']
#  ['Faculté de modifi les locaux loués' 'facu_modif']
#  ['Faculté de réaliser des travaux dans les locaux loués' 'facu_trav']
#  ["Faculté pour le Preneur de réaliser des travaux sans l'accord du Bailleur"
#   'facu_p_trav']
#  ["Faculté pour le Preneur d'apposer des plaques et/ou enseignes autorisée sans l'accord préalable du Bailleur"
#   'facu_p_plaques']
#  ['Etat de restitution des locaux loués Neuf' 'etat_neuf']
#  ['Etat de restitution des locaux loués Parfait' 'etat_parfait']
#  ['Etat de restitution des locaux loués Bon' 'etat_bon']
#  ["Etat de restitution des locaux loués Etat d'usage" 'etat_usage']
#  ["Clause d'accession" 'clause_accession']
#  ['Faculté au choix du Bailleur de demander la remise en état initial des Locaux Loués'
#   'facu_b_remise_etat']
#  ["Indemnité d'immobilisation/occupation" 'indemn_immo']
#  ["Etat des lieux d'entrée fourni en Data Room" 'edl_entree_dataroom']
#  ["Faculté de sous-location sans l'accord préalable écrit du Bailleur"
#   'facu_sousloc']
#  ["Faculté de location-gérance sans l'accord préalable écrit du Bailleur"
#   'facu_loca_gerance']
#  ["Faculté de domiciliation sans l'accord préalable écrit du Bailleur"
#   'facu_domic']
#  ["Faculté de cession du droit au Bail seul sans l'accord préalable écrit du Bailleur"
#   'facu_cess_droit_bail']
#  ["Faculté de cession du fonds de commerce sans l'accord préalable écrit du Bailleur"
#   'facu_cess_fonds_com']
#  ['Locaux indivisibles' 'locaux_indiv']
#  ['Garanties en cas de cession données par le cédant' 'garanties_cession']
#  ['Garanties en cas de cession données par le cédant Entité garantie 1er cessionnaire uniquement'
#   'gar_cess_enti_prem']
#  ['Garanties en cas de cession données par le cédant Entité garantie Cessionnaires successifs'
#   'gar_cess_enti_successifs']
#  ['Garanties en cas de cession données par le cédant durée stipulée limitée à 3 ans'
#   'gar_cess_dur_stip_3y']
#  ['Garanties en cas de cession Du cessionnaire' 'gar_cess_cessionnaire']
#  ['Droit de préemption/droit de préférence en cas de location par le Bailleur de locaux lui appartenant'
#   'droit_pref_b_app']
#  ['Droit de préemption/droit de préférence en cas de cession par le Bailleur Locaux Loués'
#   'droit_pref_b_loc_loues']
#  ['Droit de préemption/droit de préférence en cas de cession par le Bailleur Immeuble'
#   'droit_pref_b_immeuble']
#  ['Droit de préemption/droit de préférence en cas de cession par le Preneur Fonds de commerce'
#   'droit_pref_p_fonds_com']
#  ['Documents annexés au Bail Diagnostic technique amiante (DTA)'
#   'annex_dta']
#  ['Documents annexés au Bail Etat des risques (ER)' 'annex_er']
#  ['Documents annexés au Bail Diagnostique de performance énergétique (DPE)'
#   'annex_dpe']
#  ['Documents annexés au Bail Annexe environnementale' 'annex_envir']
#  ['Décret tertiaire applicable' 'decret_terti_applicable']
#  ["Installations classées pour la protection de l'environnement (ICPE)"
#   'icpe']
#  ['Stipulations intuitu personae' 'stipu_intuitu_personae']
#  ["Renonciation à l'imprévision" 'renonc_imprev']
#  ['Relations avec le preneur Impayés' 'relations_impayes']
#  ['Relations avec le preneur Echanges significatifs'
#   'relations_ech_signif']
#  ['Relations avec le preneur Différends/précontentieux'
#   'relations_precontentieux']
#  ['Commentaires Autres clauses spécifiques' 'commentaires']
#  ["Documents revus - copier coller éléments de l'index audités"
#   'index_audites']]
